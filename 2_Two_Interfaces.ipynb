# %% [markdown]
# <a href="https://colab.research.google.com/github/caiociardelli/earth323/blob/main/2_Two_Interfaces.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Two Interfaces

# %% [markdown]
# Author: Caio Ciardelli
# <br>
# Northwestern University, October 6, 2022
# <br>

# %%
import matplotlib.pyplot as plt
from matplotlib.patches import Polygon, Arc

# %%
if __name__ == '__main__':

  fig = plt.figure (figsize = (16, 8), dpi = 100)
  ax = fig.add_subplot (111)

  ax.scatter (-0.7, 0.700,
              marker = '*',
              s = 600,
              color = 'red',
              edgecolor = 'black',
              linewidth = 2,
              zorder = 10,
              label = 'Source')
  ax.scatter (0.7, 0.735,
              marker = '^',
              s = 400,
              color = 'gold',
              edgecolor = 'black',
              linewidth = 2,
              zorder = 10,
              label = 'Receiver')

  interface1 = Polygon ([[-1,  0.7],
                         [1,  0.7]],
                        closed = False,
                        color = 'black',
                        linewidth = 2)
  ax.add_patch (interface1)
  interface2 = Polygon ([[-1,  0.3],
                         [1,  0.3]],
                        closed = False,
                        color = 'black',
                        linewidth = 2)
  ax.add_patch (interface2)
  interface3 = Polygon ([[-1, -0.4],
                         [1, -0.4]],
                        closed = False,
                        color = 'black',
                        linewidth = 2)
  ax.add_patch (interface3)

  ray = Polygon ([[-0.7,  0.7],
                  [ 0.7, 0.7]],
                 closed = False,
                 color = 'red',
                 linewidth = 3)
  ax.add_patch (ray)

  ray = Polygon ([[-0.7, 0.7],
                  [-0.6, 0.3]],
                 closed = False,
                 color = 'green',
                 linewidth = 3)
  ax.add_patch (ray)
  ray = Polygon ([[-0.6, 0.3],
                  [ 0.6, 0.3]],
                 closed = False,
                 color = 'green',
                 linewidth = 3)
  ax.add_patch (ray)
  ray = Polygon ([[ 0.6, 0.3],
                  [ 0.7, 0.7]],
                 closed = False,
                 color = 'green',
                 linewidth = 3)
  ax.add_patch (ray)

  ray = Polygon ([[-0.70,  0.7],
                  [-0.55, 0.3]],
                 closed = False,
                 color = 'blue',
                 linewidth = 3)
  ax.add_patch (ray)
  ray = Polygon ([[-0.55,  0.3],
                  [-0.20, -0.4]],
                 closed = False,
                 color = 'blue',
                 linewidth = 3)
  ax.add_patch (ray)
  ray = Polygon ([[-0.20, -0.4],
                  [ 0.20, -0.4]],
                 closed = False,
                 color = 'blue',
                 linewidth = 3)
  ax.add_patch (ray)
  ray = Polygon ([[0.55,  0.3],
                  [0.20, -0.4]],
                 closed = False,
                 color = 'blue',
                 linewidth = 3)
  ax.add_patch (ray)
  ray = Polygon ([[0.70,  0.7],
                  [0.55, 0.3]],
                 closed = False,
                 color = 'blue',
                 linewidth = 3)
  ax.add_patch (ray)

  vertical = Polygon ([[-0.6, -0.1],
                       [-0.6, 0.8]],
                      closed = False,
                      color = 'black',
                      linestyle = 'dashed',
                      linewidth = 2)
  ax.add_patch (vertical)
  theta = Arc ((-0.6, 0.2), 0.35, 0.7,
               theta1 = 90,
               theta2 = 100,
               color = 'black',
               linewidth = 2,
               fill = False)
  ax.add_patch (theta)
  plt.text (-0.64, 0.64, r'$i_{12}$',
            fontsize = 20,
            ha = 'center',
            va = 'center',
            color = 'black')

  vertical = Polygon ([[-0.55, -0.1],
                       [-0.55, 0.8]],
                      closed = False,
                      color = 'black',
                      linestyle = 'dashed',
                      linewidth = 2)
  ax.add_patch (vertical)
  theta = Arc ((-0.55, 0.2), 0.35, 0.7,
               theta1 = 90,
               theta2 = 104,
               color = 'black',
               linewidth = 2,
               fill = False)
  ax.add_patch (theta)
  ax.text (-0.575,  0.64, r'$i_{13}$',
           fontsize = 20,
           ha = 'center',
           va = 'center',
           color = 'black')

  vertical = Polygon ([[-0.2, -0.8],
                       [-0.2, 0.1]],
                      closed = False,
                      color = 'black',
                      linestyle = 'dashed',
                      linewidth = 2)
  ax.add_patch (vertical)
  theta = Arc ((-0.2, -0.5), 0.35, 0.7,
               theta1 = 90,
               theta2 = 108,
               color = 'black',
               linewidth = 2,
               fill = False)
  ax.add_patch (theta)
  ax.text (-0.26, -0.06, r'$i_{23}$',
           fontsize = 20,
           ha = 'center',
           va = 'center',
           color = 'black')

  ax.text (0.8,  0.5, r'$V_1$',
           fontsize = 30,
           ha = 'center',
           va = 'center',
           color = 'black')
  ax.text (0.8, -0.1, r'$V_2$',
           fontsize = 30,
           ha = 'center',
           va = 'center',
           color = 'black')
  ax.text (0.8, -0.7, r'$V_3$',
           fontsize = 30,
           ha = 'center',
           va = 'center',
           color = 'black')

  bar = Polygon ([[-0.78,  0.7],
                  [-0.78,  0.3]],
                 closed = False,
                 color = 'black',
                 linewidth = 3)
  ups = Polygon ([[-0.80,  0.7],
                  [-0.76,  0.7]],
                 closed = False,
                 color = 'black',
                 linewidth = 3)
  dws = Polygon ([[-0.80,  0.3],
                  [-0.76,  0.3]],
                 closed = False,
                 color = 'black',
                 linewidth = 3)
  ax.add_patch (bar)
  ax.add_patch (ups)
  ax.add_patch (dws)

  bar = Polygon ([[-0.68,  0.3],
                  [-0.68, -0.4]],
                 closed = False,
                 color = 'black',
                 linewidth = 3)
  ups = Polygon ([[-0.70,  0.3],
                  [-0.66,  0.3]],
                 closed = False,
                 color = 'black',
                 linewidth = 3)
  dws = Polygon ([[-0.70, -0.4],
                  [-0.66, -0.4]],
                 closed = False,
                 color = 'black',
                 linewidth = 3)
  ax.add_patch (bar)
  ax.add_patch (ups)
  ax.add_patch (dws)

  bar = Polygon ([[-0.7, 0.83],
                  [ 0.7, 0.83]],
                 closed = False,
                 color = 'black',
                 linewidth = 3)
  lfs = Polygon ([[-0.7, 0.86],
                  [-0.7, 0.79]],
                 closed = False,
                 color = 'black',
                 linewidth = 3)
  rts = Polygon ([[0.7, 0.86],
                  [0.7, 0.79]],
                 closed = False,
                 color = 'black',
                 linewidth = 3)
  ax.add_patch (bar)
  ax.add_patch (lfs)
  ax.add_patch (rts)

  ax.text (-0.82, 0.50, r'$h_1$',
           fontsize = 25,
           ha = 'center',
           va = 'center',
           color = 'black')
  ax.text (-0.72, -0.05, r'$h_2$',
           fontsize = 25,
           ha = 'center',
           va = 'center',
           color = 'black')
  ax.text (0.00,  0.90, r'$x$',
           fontsize = 30,
           ha = 'center',
           va = 'center',
           color = 'black')

  plt.xlim (-1, 1)
  plt.ylim (-1, 1)
  plt.xticks ([])
  plt.yticks ([])

  ax.plot([], color = 'red',
          linewidth = 3,
          label = 'Direct wave')
  ax.plot([], color = 'green',
          linewidth = 3,
          label = 'First head wave')
  ax.plot([], color = 'blue',
          linewidth = 3,
          label = 'Second head wave')

  plt.legend (loc = 3, fontsize = 18)
  plt.subplots_adjust (left = 0.01, bottom = 0.01,
                       top = 0.99, right = 0.99)
  plt.axis ('off')
  plt.show ()

# %% [markdown]
# ###Direct wave

# %% [markdown]
# \begin{equation}
# t_1\,=\,\frac{x}{V_1}
# \end{equation}

# %% [markdown]
# ###First head wave

# %% [markdown]
# \begin{equation}
# t_2\,=\,\frac{x}{V_2}\,+\,\frac{2h_1\cos{i_{12}}}{V_1}
# \,=\,\frac{x}{V_2}\,+\frac{2h_1\sqrt{{V_2}^2\,-\,{V_1}^2}}{V_1V_2}
# \end{equation}

# %% [markdown]
# ####Critical distance

# %% [markdown]
# \begin{equation}
# x_{c_1}
# \,=\,\frac{2hV_1}{\sqrt{{V_2}^2\,-\,{V_1}^2}}
# \end{equation}

# %% [markdown]
# ###Second head wave

# %% [markdown]
# \begin{equation}
# t_3\,=\,\frac{x}{V_3}
#    \,+\,\frac{2h_1\cos{i_{13}}}{V_1}
#    \,+\,\frac{2h_2\cos{i_{23}}}{V_2}
# \end{equation}
# <br>
# \begin{equation}
# \sin{i_{mn}}\,=\,\frac{V_m}{V_n}
# \implies \cos{i_{mn}}\,=\,\sqrt{1\,-\,{\frac{V_m}{V_n}}^2}
# \,=\,\frac{\sqrt{{V_n}^2\,-\,{V_m}^2}}{V_n}
# \end{equation}
# <br>
# \begin{equation}
# t_3\,=\,\frac{x}{V_3}
#    \,+\,\frac{2h_1\sqrt{{V_3}^2\,-\,{V_1}^2}}{V_1V_3}
#    \,+\,\frac{2h_2\sqrt{{V_3}^2\,-\,{V_2}^2}}{V_2V_3}
# \end{equation}

# %% [markdown]
# ####Critical distance

# %% [markdown]
# \begin{equation}
# x_{c_2}
# \,=\,2h_1\tan{i_{13}}
# \,+\,2h_2\tan{i_{23}}
# \end{equation}
# <br>
# \begin{equation}
# \Downarrow
# \end{equation}
# <br>
# \begin{equation}
# x_{c_2}
# \,=\,\frac{2h_1V_1}{\sqrt{{V_3}^2\,-\,{V_1}^2}}
# \,+\,\frac{2h_2V_2}{\sqrt{{V_3}^2\,-\,{V_2}^2}}
# \end{equation}

# %%
import math
import numpy as np

# %%
def directWave (x, v1):

  return x / v1

def criticalDistance1 (h1, v1, v2):

  return 2 * h1 * v1 / math.sqrt (v2 ** 2 - v1 ** 2)

def criticalDistance2 (h1, h2, v1, v2, v3):

  return 2 * h1 * v1 / math.sqrt (v3 ** 2 - v1 ** 2) \
       + 2 * h2 * v2 / math.sqrt (v3 ** 2 - v2 ** 2)

def headWave1 (x, h1, v1, v2):

  return x / v2 + 2 * h1 * math.sqrt (v2 ** 2 - v1 ** 2) / (v1 * v2)

def headWave2 (x, v1, h1, h2, v2, v3):

  return x / v3 + 2 * h1 * math.sqrt (v3 ** 2 - v1 ** 2) / (v1 * v3) +\
                  2 * h2 * math.sqrt (v3 ** 2 - v2 ** 2) / (v2 * v3)

# %%
if __name__ == '__main__':

# Modify the parameters and re-execute the code to see
# how the travel-time curves change

  xmin = 0   # (km)
  xmax = 40  # (km)
  h1   = 2.0 # (km)
  h2   = 3.0 # (km)
  v1   = 1.7 # (km/s)
  v2   = 4.0 # (km/s)
  v3   = 6.0 # (km/s)

# %%
if __name__ == '__main__':

  plt.figure (figsize = (16, 8), dpi = 100)

  xc1 = criticalDistance1 (h1, v1, v2)
  xc2 = criticalDistance2 (h1, h2, v1, v2, v3)

  x1 = np.linspace (xmin, xmax)
  x2 = np.linspace (xc1, xmax)
  x3 = np.linspace (xc2, xmax)

  t1  = directWave (x1, v1)
  t2 = headWave1 (x2, h1, v1, v2)
  t3 = headWave2 (x3, h1, h2, v1, v2, v3)

  plt.plot (x1, t1,
            linewidth = 3,
            label = 'Direct wave')
  plt.plot (x2, t2,
            linewidth = 3,
            label = 'Head wave 1')
  plt.plot (x3, t3,
            linewidth = 3,
            label = 'Head wave 2')

  plt.title ('Travel-time curves',
             fontsize = 28,
             y = 1.05)
  plt.xlabel ('Distance from the source (km)',
              fontsize = 22,
              labelpad = 10)
  plt.ylabel ('Travel time (s)',
              fontsize = 22,
              labelpad = 10)
  plt.tick_params (axis = 'x', labelsize = 16)
  plt.tick_params (axis = 'y', labelsize = 16)
  plt.legend (loc = 2, fontsize = 18)
  plt.grid ()
  plt.show ()
